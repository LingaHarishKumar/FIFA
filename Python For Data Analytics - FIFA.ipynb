# %%
# Loading the libaries

import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# loading the dataset

fifa = pd.read_csv("players.csv")

# %%
# first 5 data

fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
# last 5 data

fifa.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
# shape - dimension

fifa.shape
# Out:
# (18278, 104)

# %%
# print all the columns

for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa["nationality"].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
fifa["nationality"].value_counts()[0:5]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
fifa["nationality"].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
plt.figure(figsize=(8,5))
plt.bar(list(fifa["nationality"].value_counts()[0:5].keys()),list(fifa["nationality"].value_counts()[0:5]),color="green")
plt.show()

# %%
player_salary = fifa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary = player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
player_salary.head()[0:5]
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color=["blue","green","red","pink","orange"])
plt.show()

# %%
# GERMANY
germany = fifa[fifa['nationality']=='Germany']
germany.head()
# Out:
#     sofifa_id                                         player_url  \
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name  age         dob  height_cm  \
# 6   M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31       M. Neuer           Manuel Neuer   33  1986-03-27        193
# 36       T. Kroos             Toni Kroos   29  1990-01-04        183
# 37        M. Reus             Marco Reus   30  1989-05-31        180
# 49     M. Hummels          Mats  Hummels   30  1988-12-16        191
#
#     weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 6          85     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# ...

# %%
germany = germany.sort_values(by=['height_cm'],ascending=False)
germany.head()
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# 1389    L. Unnerstall      Lars Unnerstall   28  1990-07-20        198
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# 11859  D. Stroh-Engel  Dominik Stroh-Engel   33  1985-11-27        197
# 13576    L. Watkowiak      Lukas Watkowiak   23  1996-03-06        197
#
#        weight_kg nationality                club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
germany = germany.sort_values(by=['weight_kg'],ascending=False)
germany.head()
# Out:
#        sofifa_id                                         player_url  \
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
#
#            short_name            long_name  age         dob  height_cm  \
# 1389    L. Unnerstall      Lars Unnerstall   28  1990-07-20        198
# 13576    L. Watkowiak      Lukas Watkowiak   23  1996-03-06        197
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# 11859  D. Stroh-Engel  Dominik Stroh-Engel   33  1985-11-27        197
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
#
#        weight_kg nationality                club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
germany = germany.sort_values(by=['wage_eur'],ascending=False)
germany.head()
# Out:
#        sofifa_id                                         player_url  \
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
#
#            short_name            long_name  age         dob  height_cm  \
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# 1389    L. Unnerstall      Lars Unnerstall   28  1990-07-20        198
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# 13576    L. Watkowiak      Lukas Watkowiak   23  1996-03-06        197
# 11859  D. Stroh-Engel  Dominik Stroh-Engel   33  1985-11-27        197
#
#        weight_kg nationality                club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending = False)
# Out:
#            short_name  wage_eur
# 1217         M. Esser     23000
# 1389    L. Unnerstall     14000
# 8016        A. Seydel      9000
# 13576    L. Watkowiak      2000
# 11859  D. Stroh-Engel      2000

# %%
shooting = fifa[['short_name','shooting']].sort_values(by=['shooting'],ascending=False)
shooting.head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
defending = fifa[['short_name','defending','nationality','club']].sort_values(by=['defending'],ascending=False)
defending.head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
bacelona = fifa[fifa['club']=='FC Barcelona']

# %%
bacelona.head(10)
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 19     176580  https://sofifa.com/player/176580/luis-suarez/2...
# 21     189511  https://sofifa.com/player/189511/sergio-busque...
# 22     194765  https://sofifa.com/player/194765/antoine-griez...
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...
# 51     189332  https://sofifa.com/player/189332/jordi-alba-ra...
# 59     205600  https://sofifa.com/player/205600/samuel-umtiti...
# 64     168651  https://sofifa.com/player/168651/ivan-rakitic/...
# 75     228702  https://sofifa.com/player/228702/frenkie-de-jo...
#
#          short_name                       long_name  age         dob  \
# 0          L. Messi  Lionel Andrés Messi Cuccittini   32  1987-06-24
# 6     M. ter Stegen           Marc-André ter Stegen   27  1992-04-30
# ...

# %%
bacelona.head(10).sort_values(by=['wage_eur'],ascending=False)
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 22     194765  https://sofifa.com/player/194765/antoine-griez...
# 19     176580  https://sofifa.com/player/176580/luis-suarez/2...
# 21     189511  https://sofifa.com/player/189511/sergio-busque...
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 64     168651  https://sofifa.com/player/168651/ivan-rakitic/...
# 51     189332  https://sofifa.com/player/189332/jordi-alba-ra...
# 59     205600  https://sofifa.com/player/205600/samuel-umtiti...
# 75     228702  https://sofifa.com/player/228702/frenkie-de-jo...
#
#          short_name                       long_name  age         dob  \
# 0          L. Messi  Lionel Andrés Messi Cuccittini   32  1987-06-24
# 22     A. Griezmann               Antoine Griezmann   28  1991-03-21
# ...

# %%
bacelona.head(10).sort_values(by=['shooting'],ascending=False)
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 19     176580  https://sofifa.com/player/176580/luis-suarez/2...
# 22     194765  https://sofifa.com/player/194765/antoine-griez...
# 64     168651  https://sofifa.com/player/168651/ivan-rakitic/...
# 51     189332  https://sofifa.com/player/189332/jordi-alba-ra...
# 75     228702  https://sofifa.com/player/228702/frenkie-de-jo...
# 59     205600  https://sofifa.com/player/205600/samuel-umtiti...
# 21     189511  https://sofifa.com/player/189511/sergio-busque...
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
#
#          short_name                       long_name  age         dob  \
# 0          L. Messi  Lionel Andrés Messi Cuccittini   32  1987-06-24
# 19        L. Suárez        Luis Alberto Suárez Díaz   32  1987-01-24
# ...

# %%
bacelona.head(10).sort_values(by=['defending'],ascending=False)
# Out:
#     sofifa_id                                         player_url  \
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...
# 59     205600  https://sofifa.com/player/205600/samuel-umtiti...
# 21     189511  https://sofifa.com/player/189511/sergio-busque...
# 51     189332  https://sofifa.com/player/189332/jordi-alba-ra...
# 75     228702  https://sofifa.com/player/228702/frenkie-de-jo...
# 64     168651  https://sofifa.com/player/168651/ivan-rakitic/...
# 22     194765  https://sofifa.com/player/194765/antoine-griez...
# 19     176580  https://sofifa.com/player/176580/luis-suarez/2...
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
#
#          short_name                       long_name  age         dob  \
# 29            Piqué           Gerard Piqué Bernabéu   32  1987-02-02
# 59        S. Umtiti                   Samuel Umtiti   25  1993-11-14
# ...

# %%
bacelona['nationality'].value_counts()
# Out:
# Spain          15
# France          5
# Brazil          3
# Netherlands     2
# Argentina       1
# Germany         1
# Uruguay         1
# Croatia         1
# Chile           1
# Portugal        1
# Senegal         1
# Japan           1
# Name: nationality, dtype: int64
